# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
##data

# %%
df = pd.read_csv(r'C:\Users\new\Desktop\US_Accidents_Dec20_Updated.csv')

# %%
##data preparation and cleaning

# %%
df
# Out:
#                 ID  Severity           Start_Time             End_Time  \
# 0              A-1         2  2019-05-21 08:29:55  2019-05-21 09:29:40
# 1              A-2         2  2019-10-07 17:43:09  2019-10-07 19:42:50
# 2              A-3         2  2020-12-13 21:53:00  2020-12-13 22:44:00
# 3              A-4         2  2018-04-17 16:51:23  2018-04-17 17:50:46
# 4              A-5         3  2016-08-31 17:40:49  2016-08-31 18:10:49
# ...            ...       ...                  ...                  ...
# 2906605  A-2906606         2  2018-06-28 08:49:01  2018-06-28 09:18:51
# 2906606  A-2906607         2  2019-01-10 02:01:01  2019-01-10 02:30:32
# 2906607  A-2906608         2  2020-11-23 12:52:00  2020-11-24 00:47:37
# 2906608  A-2906609         2  2019-12-29 22:38:00  2019-12-29 23:38:00
# 2906609  A-2906610         2  2018-03-26 13:35:03  2018-03-26 14:39:00
#
#          Start_Lat   Start_Lng    End_Lat     End_Lng  Distance(mi)  \
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat', 'Start_Lng',
#        'End_Lat', 'End_Lng', 'Distance(mi)', 'Description', 'Number', 'Street',
#        'Side', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2906610 entries, 0 to 2906609
# Data columns (total 47 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Severity               int64
#  2   Start_Time             object
#  3   End_Time               object
#  4   Start_Lat              float64
#  5   Start_Lng              float64
#  6   End_Lat                float64
#  7   End_Lng                float64
#  8   Distance(mi)           float64
#  9   Description            object
#  10  Number                 float64
#  11  Street                 object
#  12  Side                   object
#  13  City                   object
#  14  County                 object
#  15  State                  object
#  16  Zipcode                object
#  17  Country                object
#  18  Timezone               object
#  19  Airport_Code           object
#  20  Weather_Timestamp      object
# ...

# %%
df.describe()
# Out:
#            Severity     Start_Lat     Start_Lng       End_Lat       End_Lng  \
# count  2.906610e+06  2.906610e+06  2.906610e+06  2.623789e+06  2.623789e+06
# mean   2.288649e+00  3.653027e+01 -9.642676e+01  3.651733e+01 -9.620367e+01
# std    5.541618e-01  5.013964e+00  1.775412e+01  5.016609e+00  1.765971e+01
# min    1.000000e+00  2.455527e+01 -1.246238e+02  2.455527e+01 -1.246238e+02
# 25%    2.000000e+00  3.366453e+01 -1.178232e+02  3.364659e+01 -1.177020e+02
# 50%    2.000000e+00  3.609977e+01 -9.116690e+01  3.605898e+01 -9.105163e+01
# 75%    3.000000e+00  4.037505e+01 -8.085814e+01  4.033133e+01 -8.084679e+01
# max    4.000000e+00  4.900220e+01 -6.711317e+01  4.907500e+01 -6.710924e+01
#
#        Distance(mi)        Number  Temperature(F)  Wind_Chill(F)  \
# count  2.906610e+06  1.014938e+06    2.839386e+06   1.722751e+06
# mean   3.980541e-01  6.789728e+03    6.098873e+01   5.499048e+01
# std    1.592556e+00  1.697225e+04    1.845258e+01   2.219542e+01
# ...

# %%
## Ask and answer questions
##1. Are there more accidents in warmer or colder areas?
##2. Which states have the most top 5 accidents?

# %%
## Fingding missing values percentage per column
missing_per = df.isna().sum().sort_values(ascending = False)/len(df)

# %%
##plotting columns with missing values
missing_per[missing_per != 0].plot(kind = 'barh')
# Out:
# <AxesSubplot:>

# %%
## EDA and Vizulation

##Columns to analyze
## 1.City
## 2.Start Time 
## 3. Start Lat, Start Lng
## 4.Temperature 
## 5. Weather Condition

# %%
## CITY COlUMN

# %%
cities = df.City.unique()
len(cities)
# Out:
# 11790

# %%
cities_by_accident = df.City.value_counts()
cities_by_accident[:20].plot(kind = 'barh')
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns
sns.set_style('darkgrid')

# %%
sns.histplot(cities_by_accident, log_scale = True)
# Out:
# <AxesSubplot:xlabel='City', ylabel='Count'>

# %%
#Percentage of cities with accidents more than 1000
high_acc_ct = cities_by_accident[cities_by_accident >= 1000]
low_acc_ct = cities_by_accident[cities_by_accident <1000]
len(high_acc_ct)/len(cities_by_accident)
# Out:
# 0.04351514123335313

# %%
## START TIME COLUMN

# %%
df.Start_Time[0]
# Out:
# '2019-05-21 08:29:55'

# %%
df.Start_Time = pd.to_datetime(df.Start_Time)
sns.distplot(df.Start_Time.dt.hour, bins = 24, kde = False, norm_hist = True)
# Out:
# C:\Users\new\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Start_Time'>

# %%
sns.distplot(df.Start_Time.dt.dayofweek, bins = 7, kde = False, norm_hist = True)
# Out:
# <AxesSubplot:xlabel='Start_Time'>

# %%
sundays_start_time = df.Start_Time[df.Start_Time.dt.dayofweek == 6]
sns.distplot(sundays_start_time.dt.hour, bins = 24, kde = False, norm_hist = True)
# Out:
# C:\Users\new\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Start_Time'>

# %%
mondays_start_time = df.Start_Time[df.Start_Time.dt.dayofweek == 0]
sns.distplot(mondays_start_time.dt.hour, bins = 24, kde = False, norm_hist = True)
# Out:
# C:\Users\new\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Start_Time'>

# %%
sns.distplot(mondays_start_time.dt.month, bins = 12, kde = False, norm_hist = True)
# Out:
# <AxesSubplot:xlabel='Start_Time'>

# %%
df_2019 = df[df.Start_Time.dt.year == 2019]
sns.distplot(df_2019.Start_Time.dt.month, bins = 12, kde = False, norm_hist = True)
# Out:
# C:\Users\new\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Start_Time'>

# %%
## START LAT and START LONG

# %%
df.Start_Lat
# Out:
# 0          34.808868
# 1          35.090080
# 2          37.145730
# 3          39.110390
# 4          26.102942
#              ...
# 2906605    29.813824
# 2906606    34.068890
# 2906607    25.702200
# 2906608    40.660140
# 2906609    38.831749
# Name: Start_Lat, Length: 2906610, dtype: float64

# %%
df.Start_Lng
# Out:
# 0          -82.269157
# 1          -80.745560
# 2         -121.985052
# 3         -119.773781
# 4          -80.265091
#               ...
# 2906605    -95.399437
# 2906606   -117.342010
# 2906607    -80.335556
# 2906608   -111.952460
# 2906609   -104.748161
# Name: Start_Lng, Length: 2906610, dtype: float64

# %%
sns.scatterplot(x= df.Start_Lng, y = df.Start_Lat, size = 0.001)
# Out:
# <AxesSubplot:xlabel='Start_Lng', ylabel='Start_Lat'>

# %%
import folium
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-85-173c1173bf1c> in <module>
# ----> 1 import folium
#
# ModuleNotFoundError: No module named 'folium'

# %%
##Summary 
1.The number of accidents per city decreases exponentially
2.Less than 5% of cities have more than 1000 accidents in a year
3. A high percentage of accidents occur between 6 am to 10 am (probably a rush hour), next highest percentage is 3 pm to 6 pm.
4.On sundays peak occurs between 10 am to 3 pm , unlike weekdays.
5. Much data is missing for 2016 and maybe 2017.
